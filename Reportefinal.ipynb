# %% [markdown]
# ## Visitando repositorios de tesis de Estadística
#
# Repositorios elegidos:
#
# - Repositorio de Tesis de la Escuela Profesional de Estadística de la Universidad Nacional de Piura
#
#     Enlace: https://repositorio.unp.edu.pe/handle/UNP/1304
#
# - Repositorio de Tesis de Ingeniería Informática de la Pontificia Universidad Católica del Perú
#
#     Enlace: https://tesis.pucp.edu.pe/repositorio/handle/20.500.12404/14
#
# - Repositorio de Tesis de Fin de Grado de Estadística Empresarial de la Universidad Miguel Hernandez de Elche
#
#     Enlace: http://dspace.umh.es/handle/11000/28371

# %% [markdown]
# ### 1. Importando las librerias a usar

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
#Comenzamos instalando la librería request para una mejor petición o solicitud HTTP.
#Luego importamos BeautifulSoup para poder extraer información de documentos HTML, sirve para la webscraping."
#Por último pandas que será usado para el dataframe.

# %% [markdown]
# ### 2. Leyendo el primer repositorio de la Universidad Nacional de Piura

# %%
import requests
from bs4 import BeautifulSoup as bs

#  1. Requerimiento 

website = 'https://repositorio.unp.edu.pe/handle/20.500.12676/3728?show=full'
print('Haciendo una solicitud a:\n')
print(website)

unp = requests.get(website)
unp #Indica el status. 200 significa 'Respuesta satisfactoria'
# Out:
# Haciendo una solicitud a:
#
# https://repositorio.unp.edu.pe/handle/20.500.12676/3728?show=full
# <Response [200]>

# %%
#  2. Scrapear con BS

    # a. Almacenar el texto en una 'sopa'
    
soup = bs(unp.text,'lxml') #'lxml' es el parse que pide la fx
                        # Lo que hace es dividir el texto en 
                            # pequenos pedazos identificables
                        # El resultado es una 'sopa', asi se le dice
    # c. Imprimir texto
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/themes/Mirage2/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/themes/Mirage2/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <meta content="DSpace 6.3" name="Generator"/>
#   <script crossorigin="anonymous" integrity="sha384-3LK/3kTpDE/Pkp8gTNp2gR/2gOiwQ6QaO7Td0zV76UFJVhqLl4Vl3KL1We6q6wR9" src="https://use.fontawesome.com/releases/v5.1.0/js/all.js">
#   </script>
#   <link href="/themes/Mirage2/styles/main.css" rel="stylesheet"/>
#   <link href="https://repositorio.unp.edu.pe:443/open-search/description.xml" rel="search" title="DSpace" type="application/opensearchdescription+xml"/>
#   <script>
#    //Clear default text of empty text areas on focus
#                 function tFocus(element)
#                 {
#                 if (element.value == ' '){element.value='';}
#                 }
#                 //Clear default text of empty text areas on submit
#                 function tSubmit(form)
#                 {
#                 var defaultedElements = document.getElementsByTagName("textarea");
#                 for (var i=0; i != defaultedElements.length; i++){
#                 if (defaultedElements[i].value == ' '){
#                 defaultedElements[i].value='';}}
#                 }
#                 //Disable pressing 'enter' key to submit a form (otherwise pressing 'enter' causes a submission to start over)
#                 function disableEnterKey(e)
#                 {
#                 var key;
#
#                 if(window.event)
#                 key = window.event.keyCode;     //Internet Explorer
#                 else
#                 key = e.which;     //Firefox and Netscape
#
#                 if(key == 13)  //if "Enter" pressed, then disable!
#                 return false;
#                 else
#                 return true;
#                 }
#   </script>
#   <!--[if lt IE 9]>
#                 <script src="/themes/Mirage2/vendor/html5shiv/dist/html5shiv.js"> </script>
#                 <script src="/themes/Mirage2/vendor/respond/dest/respond.min.js"> </script>
#                 <![endif]-->
#   <script src="/themes/Mirage2/vendor/modernizr/modernizr.js">
#   </script>
#   <title>
#    Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022
#   </title>
#   <link href="http://purl.org/dc/terms/" rel="schema.DCTERMS"/>
#   <link href="http://purl.org/dc/elements/1.1/" rel="schema.DC"/>
#   <meta content="Cabrera Prieto, Carlos Eduardo" name="DC.contributor" xml:lang="es_PE"/>
#   <meta content="Facundo Farfán, Jean Carlos" name="DC.creator" xml:lang="es_PE"/>
#   <meta content="2022-09-01T16:12:11Z" name="DCTERMS.dateAccepted" scheme="DCTERMS.W3CDTF"/>
#   <meta content="2022-09-01T16:12:11Z" name="DCTERMS.available" scheme="DCTERMS.W3CDTF"/>
#   <meta content="2021" name="DCTERMS.issued" scheme="DCTERMS.W3CDTF"/>
#   <meta content="http://repositorio.unp.edu.pe/handle/20.500.12676/3728" name="DC.identifier" scheme="DCTERMS.URI"/>
#   <meta content="Como es bien sabido, desde hace muchos años, la deuda pública externa, está constituida por los créditos externos recibidos, donde estos pueden ser tanto públicos como privados. Siempre existe la participación activa de organismos privados, particulares, incluso instituciones financieras internacionales en la negociación de la deuda externa, una de las características más importantes es que la deuda externa se paga en países extranjeros. Desde hace muchos años; aproximadamente durante los años 70´s, tiempos en los que el comercio internacional se encontraba en pleno auge, diversos países tanto los de América Latina como algunos otros, alrededor del mundo, no siendo Perú la excepción, registraron significativos crecimientos en cada una de sus economías. Este crecimiento está influenciado principalmente por dos factores: en primer lugar, la exportación de productos terminados aumenta aún más, lo que conduce a condiciones comerciales significativamente mejores, fácil entrada al mercado debido a la disponibilidad y la rentabilidad, capacidad relativamente baja. Estos factores, además del acceso al crédito externo, han propiciado un aumento significativo de cada inversión durante la fase de planificación del desarrollo del modelo y del papel del Estado como empresario, inversionista y gestor empresarial. En general, aún se mantienen las políticas de apoyo al desarrollo. Sin embargo, muchas inversiones se realizan sin una evaluación cuidadosa de las necesidades y el potencial de todos y cada uno de los países y, por lo tanto, no contribuyen de manera proporcional al crecimiento económico. Cuando todos estos eventos se dieron, trajeron una serie de cambios negativos para los países en desarrollo: por un lado, sus condiciones comerciales se deterioraron significativamente debido a los mayores precios del petróleo, por otro lado, incurren en mayores costos de deuda externa debido a los altos precios del petróleo. tipos de interés a corto plazo. Se conoce, que la deuda pública externa a nivel mundial ha ido variando mucho en el transcurrir del tiempo, siendo Estados Unidos uno de los principales países con una deuda pública bastante alta, es incluso con una deuda mucho mayor que su PBI, considerando que en el 2016 tuvo un incremento de un 0.8%. Un documento del Fondo Monetario Internacional, redactado en el 2015 y publicado a través del Foro Económico Mundial (WEF), describe que Japón es una de las naciones más endeudadas del mundo y que ha estado luchando contra el estancamiento por más de 20 años. En América Latina y el Caribe, CEPAL que pertenece a las Naciones Unidas, en ese mismo año afirmó que Argentina era el país con una mayor deuda pública externa. Porter, en el año 2010, definió al Perú como un mercado emergente con la capacidad suficiente de poder seguir creciendo con nuestra propia producción industrial y ventas al exterior que requieren la inversión de sus residentes, ya que tantos países, incluido el nuestro, para financiar todas esas inversiones ya mencionadas, requieren de capital que no disponen en cantidades suficientes. De esta manera, los países de economía baja buscan la ayuda en el mercado internacional, en donde los flujos de ahorro del mercado internacional se encuentran representados por dos formas: la Inversión Extranjera Directa (IED) y el endeudamiento (préstamos, bonos) en la cual, la mayoría de los países optan por endeudarse. Esta deuda, formada por préstamos o bonos tienen una obligación (interés) que debe ser asumida con responsabilidad por el Estado Peruano; ya que, por el momento, el Estado Peruano, no sabe cómo poder sacar provecho de esta deuda con el mercado internacional, y que si hubiese un mal financiamiento de estos fondos, sabemos que existe un compromiso (contrato) que no puede ser ignorado o desconocido y se deberá cumplir en el plazo estipulado de tiempo. El presente proyecto de tesis tiene como objetivo principal el dar a conocer la deuda pública externa peruana de los últi ...
#   <meta content="application/pdf" name="DC.format" xml:lang="es_PE"/>
#   <meta content="spa" name="DC.language" scheme="DCTERMS.RFC1766" xml:lang="es_PE"/>
#   <meta content="Universidad Nacional de Piura" name="DC.publisher" xml:lang="es_PE"/>
#   <meta content="info:eu-repo/semantics/openAccess" name="DC.rights" xml:lang="es_PE"/>
#   <meta content="Attribution-NonCommercial-NoDerivatives 4.0 Internacional" name="DC.rights" xml:lang="*"/>
#   <meta content="http://creativecommons.org/licenses/by-nc-nd/4.0/" name="DC.rights" scheme="DCTERMS.URI" xml:lang="*"/>
#   <meta content="Universidad Nacional de Piura" name="DC.source" xml:lang="es_PE"/>
#   <meta content="Repositorio Institucional Digital - UNP" name="DC.source" xml:lang="es_PE"/>
#   <meta content="deuda pública externa" name="DC.subject" xml:lang="es_PE"/>
#   <meta content="participación activa" name="DC.subject" xml:lang="es_PE"/>
#   <meta content="pronósticos trimestrales" name="DC.subject" xml:lang="es_PE"/>
#   <meta content="Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022" name="DC.title" xml:lang="es_PE"/>
#   <meta content="info:eu-repo/semantics/bachelorThesis" name="DC.type" xml:lang="es_PE"/>
#   <meta content="http://purl.org/pe-repo/ocde/ford#1.01.03" name="DC.subject" xml:lang="es_PE"/>
#   <meta content="PE" name="DC.publisher" xml:lang="es_PE"/>
#   <meta content="info:eu-repo/semantics/publishedVersion" name="DC.type" xml:lang="es_PE"/>
#   <meta content="deuda pública externa; participación activa; pronósticos trimestrales; info:eu-repo/semantics/bachelorThesis" name="citation_keywords"/>
#   <meta content="Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022" name="citation_title"/>
#   <meta content="Universidad Nacional de Piura" name="citation_publisher"/>
#   <meta content="spa" name="citation_language"/>
#   <meta content="Facundo Farfán, Jean Carlos" name="citation_author"/>
#   <meta content="http://repositorio.unp.edu.pe/bitstream/20.500.12676/3728/1/ESTA-FAC-FAR-2021.pdf" name="citation_pdf_url"/>
#   <meta content="2021" name="citation_date"/>
#   <meta content="http://repositorio.unp.edu.pe/handle/20.500.12676/3728" name="citation_abstract_html_url"/>
#  </head>
#  <body>
#   <header>
#    <div class="navbar navbar-default navbar-static-top" role="navigation">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-toggle="offcanvas" type="button">
#        <span class="sr-only">
#         Cambiar navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a href="/">
#        <img src="/themes/Mirage2/images/logounp.png" style="display:block;height:auto;max-width:100%;"/>
#       </a>
#       <div class="navbar-header pull-right visible-xs hidden-sm hidden-md hidden-lg">
#        <ul class="nav nav-pills pull-left">
#         <li>
#          <form action="/login" method="get" style="display: inline">
#           <button class="navbar-toggle navbar-link">
#            <b aria-hidden="true" class="visible-xs glyphicon glyphicon-user">
#            </b>
#           </button>
#          </form>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="navbar-header pull-right hidden-xs">
#       <ul class="nav navbar-nav pull-left">
#       </ul>
#       <ul class="nav navbar-nav pull-left">
#        <li>
#         <a href="/login">
#          <span class="hidden-xs">
#           Login
#          </span>
#         </a>
#        </li>
#       </ul>
#       <button class="navbar-toggle visible-sm" data-toggle="offcanvas" type="button">
#        <span class="sr-only">
#         Cambiar navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="trail-wrapper hidden-print">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12">
#       <div class="breadcrumb dropdown visible-xs">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="trail-dropdown-toggle" role="button">
#         Ver ítem
#         <b class="caret">
#         </b>
#        </a>
#        <ul aria-labelledby="trail-dropdown-toggle" class="dropdown-menu" role="menu">
#         <li role="presentation">
#          <a href="/" role="menuitem">
#           <i aria-hidden="true" class="glyphicon glyphicon-home">
#           </i>
#           Repositorio Institucional UNP
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/UNP/1043" role="menuitem">
#           Facultad de Ciencias
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/UNP/1304" role="menuitem">
#           Escuela Profesional de Estadística
#          </a>
#         </li>
#         <li class="disabled" role="presentation">
#          <a href="#" role="menuitem">
#           Ver ítem
#          </a>
#         </li>
#        </ul>
#       </div>
#       <ul class="breadcrumb hidden-xs">
#        <li>
#         <i aria-hidden="true" class="glyphicon glyphicon-home">
#         </i>
#         <a href="/">
#          Repositorio Institucional UNP
#         </a>
#        </li>
#        <li>
#         <a href="/handle/UNP/1043">
#          Facultad de Ciencias
#         </a>
#        </li>
#        <li>
#         <a href="/handle/UNP/1304">
#          Escuela Profesional de Estadística
#         </a>
#        </li>
#        <li class="active">
#         Ver ítem
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="hidden" id="no-js-warning-wrapper">
#    <div id="no-js-warning">
#     <div class="notice failure">
#      JavaScript is disabled for your browser. Some features of this site may not work without it.
#     </div>
#    </div>
#   </div>
#   <div class="container" id="main-container">
#    <div class="row row-offcanvas row-offcanvas-right">
#     <div class="horizontal-slider clearfix">
#      <div class="col-xs-12 col-sm-12 col-md-9 main-content">
#       <div>
#        <div class="ds-static-div primary" id="aspect_artifactbrowser_ItemViewer_div_item-view">
#         <p class="ds-paragraph item-view-toggle item-view-toggle-top">
#          <a href="/handle/20.500.12676/3728">
#           Mostrar el registro sencillo del ítem
#          </a>
#         </p>
#         <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/3728/mets.xml-->
#         <h2 class="page-header first-page-header">
#          Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022
#         </h2>
#         <div class="ds-table-responsive">
#          <table class="ds-includeSet-table detailtable table table-striped table-hover">
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.contributor.advisor
#            </td>
#            <td class="word-break">
#             Cabrera Prieto, Carlos Eduardo
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.contributor.author
#            </td>
#            <td class="word-break">
#             Facundo Farfán, Jean Carlos
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.date.accessioned
#            </td>
#            <td class="word-break">
#             2022-09-01T16:12:11Z
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.date.available
#            </td>
#            <td class="word-break">
#             2022-09-01T16:12:11Z
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.date.issued
#            </td>
#            <td class="word-break">
#             2021
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.identifier.uri
#            </td>
#            <td class="word-break">
#             http://repositorio.unp.edu.pe/handle/20.500.12676/3728
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.description.abstract
#            </td>
#            <td class="word-break">
#             Como es bien sabido, desde hace muchos años, la deuda pública externa, está constituida por los créditos externos recibidos, donde estos pueden ser tanto públicos como privados. Siempre existe la participación activa de organismos privados, particulares, incluso instituciones financieras internacionales en la negociación de la deuda externa, una de las características más importantes es que la deuda externa se paga en países extranjeros. Desde hace muchos años; aproximadamente durante los años 70´s, tiempos en los que el comercio internacional se encontraba en pleno auge, diversos países tanto los de América Latina como algunos otros, alrededor del mundo, no siendo Perú la excepción, registraron significativos crecimientos en cada una de sus economías. Este crecimiento está influenciado principalmente por dos factores: en primer lugar, la exportación de productos terminados aumenta aún más, lo que conduce a condiciones comerciales significativamente mejores, fácil entrada al mercado debido a la disponibilidad y la rentabilidad, capacidad relativamente baja. Estos factores, además del acceso al crédito externo, han propiciado un aumento significativo de cada inversión durante la fase de planificación del desarrollo del modelo y del papel del Estado como empresario, inversionista y gestor empresarial. En general, aún se mantienen las políticas de apoyo al desarrollo. Sin embargo, muchas inversiones se realizan sin una evaluación cuidadosa de las necesidades y el potencial de todos y cada uno de los países y, por lo tanto, no contribuyen de manera proporcional al crecimiento económico. Cuando todos estos eventos se dieron, trajeron una serie de cambios negativos para los países en desarrollo: por un lado, sus condiciones comerciales se deterioraron significativamente debido a los mayores precios del petróleo, por otro lado, incurren en mayores costos de deuda externa debido a los altos precios del petróleo. tipos de interés a corto plazo. Se conoce, que la deuda pública externa a nivel mundial ha ido variando mucho en el transcurrir del tiempo, siendo Estados Unidos uno de los principales países con una deuda pública bastante alta, es incluso con una deuda mucho mayor que su PBI, considerando que en el 2016 tuvo un incremento de un 0.8%. Un documento del Fondo Monetario Internacional, redactado en el 2015 y publicado a través del Foro Económico Mundial (WEF), describe que Japón es una de las naciones más endeudadas del mundo y que ha estado luchando contra el estancamiento por más de 20 años. En América Latina y el Caribe, CEPAL que pertenece a las Naciones Unidas, en ese mismo año afirmó que Argentina era el país con una mayor deuda pública externa. Porter, en el año 2010, definió al Perú como un mercado emergente con la capacidad suficiente de poder seguir creciendo con nuestra propia producción industrial y ventas al exterior que requieren la inversión de sus residentes, ya que tantos países, incluido el nuestro, para financiar todas esas inversiones ya mencionadas, requieren de capital que no disponen en cantidades suficientes. De esta manera, los países de economía baja buscan la ayuda en el mercado internacional, en donde los flujos de ahorro del mercado internacional se encuentran representados por dos formas: la Inversión Extranjera Directa (IED) y el endeudamiento (préstamos, bonos) en la cual, la mayoría de los países optan por endeudarse. Esta deuda, formada por préstamos o bonos tienen una obligación (interés) que debe ser asumida con responsabilidad por el Estado Peruano; ya que, por el momento, el Estado Peruano, no sabe cómo poder sacar provecho de esta deuda con el mercado internacional, y que si hubiese un mal financiamiento de estos fondos, sabemos que existe un compromiso (contrato) que no puede ser ignorado o desconocido y se deberá cumplir en el plazo estipulado de tiempo. El presente proyecto de tesis tiene como objetivo principal el dar a conocer la deuda pública externa peruana de los últimos 2 ...
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.format
#            </td>
#            <td class="word-break">
#             application/pdf
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.language.iso
#            </td>
#            <td class="word-break">
#             spa
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.publisher
#            </td>
#            <td class="word-break">
#             Universidad Nacional de Piura
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.rights
#            </td>
#            <td class="word-break">
#             info:eu-repo/semantics/openAccess
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.rights
#            </td>
#            <td class="word-break">
#             Attribution-NonCommercial-NoDerivatives 4.0 Internacional
#            </td>
#            <td>
#             *
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.rights.uri
#            </td>
#            <td class="word-break">
#             http://creativecommons.org/licenses/by-nc-nd/4.0/
#            </td>
#            <td>
#             *
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.source
#            </td>
#            <td class="word-break">
#             Universidad Nacional de Piura
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.source
#            </td>
#            <td class="word-break">
#             Repositorio Institucional Digital - UNP
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             deuda pública externa
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             participación activa
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject
#            </td>
#            <td class="word-break">
#             pronósticos trimestrales
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.title
#            </td>
#            <td class="word-break">
#             Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.type
#            </td>
#            <td class="word-break">
#             info:eu-repo/semantics/bachelorThesis
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             thesis.degree.name
#            </td>
#            <td class="word-break">
#             Licenciado en Estadística
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             thesis.degree.grantor
#            </td>
#            <td class="word-break">
#             Universidad Nacional de Piura. Facultad de Ciencias
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             thesis.degree.discipline
#            </td>
#            <td class="word-break">
#             Estadística
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             dc.subject.ocde
#            </td>
#            <td class="word-break">
#             http://purl.org/pe-repo/ocde/ford#1.01.03
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.publisher.country
#            </td>
#            <td class="word-break">
#             PE
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             renati.juror
#            </td>
#            <td class="word-break">
#             Vargas Lynch, Conrrado Sigisfredo
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             renati.juror
#            </td>
#            <td class="word-break">
#             Correa Becerra, Ramón Cosme
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             renati.juror
#            </td>
#            <td class="word-break">
#             Abanto Cerna, Lemin
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             renati.discipline
#            </td>
#            <td class="word-break">
#             542016
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             renati.level
#            </td>
#            <td class="word-break">
#             http://purl.org/pe-repo/renati/nivel#tituloProfesional
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             renati.advisor.dni
#            </td>
#            <td class="word-break">
#             17876062
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             renati.type
#            </td>
#            <td class="word-break">
#             http://purl.org/pe-repo/renati/type#tesis
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             renati.advisor.orcid
#            </td>
#            <td class="word-break">
#             https://orcid.org/0000-0002-8528-0472
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#           <tr class="ds-table-row even">
#            <td class="label-cell">
#             renati.author.dni
#            </td>
#            <td class="word-break">
#             72029939
#            </td>
#            <td>
#            </td>
#           </tr>
#           <tr class="ds-table-row odd">
#            <td class="label-cell">
#             dc.type.version
#            </td>
#            <td class="word-break">
#             info:eu-repo/semantics/publishedVersion
#            </td>
#            <td>
#             es_PE
#            </td>
#           </tr>
#          </table>
#         </div>
#         <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F3728&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17876062&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-8528-0472&amp;rft.author=72029939">
#          ﻿
#         </span>
#         <h3>
#          Ficheros en el ítem
#         </h3>
#         <div class="file-list">
#          <div class="file-wrapper row">
#           <div class="col-xs-6 col-sm-3">
#            <div class="thumbnail">
#             <a class="image-link" href="/bitstream/handle/20.500.12676/3728/ESTA-FAC-FAR-2021.pdf?sequence=1&amp;isAllowed=y">
#              <img alt="Thumbnail" class="img-thumbnail" data-src="holder.js/100%x160/text:No Thumbnail"/>
#             </a>
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-7">
#            <dl class="file-metadata dl-horizontal">
#             <dt>
#              Nombre:
#             </dt>
#             <dd class="word-break" title="ESTA-FAC-FAR-2021.pdf">
#              ESTA-FAC-FAR-2021.pdf
#             </dd>
#             <dt>
#              Tamaño:
#             </dt>
#             <dd class="word-break">
#              1.513Mb
#             </dd>
#             <dt>
#              Formato:
#             </dt>
#             <dd class="word-break">
#              PDF
#             </dd>
#            </dl>
#           </div>
#           <div class="file-link col-xs-6 col-xs-offset-6 col-sm-2 col-sm-offset-0">
#            <a href="/bitstream/handle/20.500.12676/3728/ESTA-FAC-FAR-2021.pdf?sequence=1&amp;isAllowed=y">
#             Ver/
#            </a>
#           </div>
#          </div>
#          <div class="file-wrapper row">
#           <div class="col-xs-6 col-sm-3">
#            <div class="thumbnail">
#             <a class="image-link" href="/bitstream/handle/20.500.12676/3728/license_rdf?sequence=2&amp;isAllowed=y">
#              <img alt="Thumbnail" class="img-thumbnail" data-src="holder.js/100%x160/text:No Thumbnail"/>
#             </a>
#            </div>
#           </div>
#           <div class="col-xs-6 col-sm-7">
#            <dl class="file-metadata dl-horizontal">
#             <dt>
#              Nombre:
#             </dt>
#             <dd class="word-break" title="license_rdf">
#              license_rdf
#             </dd>
#             <dt>
#              Tamaño:
#             </dt>
#             <dd class="word-break">
#              805bytes
#             </dd>
#             <dt>
#              Formato:
#             </dt>
#             <dd class="word-break">
#              application/rdf+xml
#             </dd>
#            </dl>
#           </div>
#           <div class="file-link col-xs-6 col-xs-offset-6 col-sm-2 col-sm-offset-0">
#            <a href="/bitstream/handle/20.500.12676/3728/license_rdf?sequence=2&amp;isAllowed=y">
#             Ver/
#            </a>
#           </div>
#          </div>
#         </div>
#         <h3 class="ds-list-head">
#          Este ítem aparece en la(s) siguiente(s) colección(ones)
#         </h3>
#         <ul class="ds-referenceSet-list">
#          <!-- External Metadata URL: cocoon://metadata/handle/UNP/1304/mets.xml-->
#          <li>
#           <a href="/handle/UNP/1304">
#            Escuela Profesional de Estadística
#           </a>
#           [25]
#           <br/>
#           Escuela Profesional de Estadística - UNP
#          </li>
#         </ul>
#         <p class="ds-paragraph item-view-toggle item-view-toggle-bottom">
#          <a href="/handle/20.500.12676/3728">
#           Mostrar el registro sencillo del ítem
#          </a>
#         </p>
#        </div>
#        <div about="http://repositorio.unp.edu.pe/handle/20.500.12676/3728" class="row">
#         <div class="col-sm-3 col-xs-12">
#          <a alt="info:eu-repo/semantics/openAccess" href="http://creativecommons.org/licenses/by-nc-nd/4.0/" rel="license" title="info:eu-repo/semantics/openAccess">
#           <img alt="info:eu-repo/semantics/openAccess" class="img-responsive" src="/themes/Mirage2//images/creativecommons/cc-by-nc-nd.png"/>
#          </a>
#         </div>
#         <div class="col-sm-8">
#          <span>
#           Excepto si se señala otra cosa, la licencia del ítem se describe como info:eu-repo/semantics/openAccess
#          </span>
#         </div>
#        </div>
#       </div>
#       <div class="visible-xs visible-sm">
#        <div>
#         <div class="col-xs-2">
#          <a href="#" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/logor2.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="//scholar.google.com/" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/googleacademico.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="//duraspace.org/" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/duraspace.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="//alicia.concytec.gob.pe/" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/alicia.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="http://roar.eprints.org/1348/" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/roar.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="https://v2.sherpa.ac.uk/id/repository/4814" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/opendoar.png"/>
#          </a>
#         </div>
#        </div>
#        <footer>
#         <div class="row">
#          <div class="col-xs-12 bg-primary">
#           <h5>
#            Universidad Nacional de Piura
#           </h5>
#           <p>
#            Urb. Miraflores s/n, Castilla-Piura Apartado Postal 295 - Perú | Telf. (51 73) 284700 – 285251 Fax (51 73) 34-3349
#           </p>
#           <p>
#            Todos los contenidos de repositorio.unp.edu.pe están bajo la Licencia Creative Commons
#           </p>
#           <p>
#            <a href="mailto:repositorio@unp.edu.pe" style="color: #FFF;">
#             repositorio@unp.edu.pe
#            </a>
#           </p>
#          </div>
#         </div>
#        </footer>
#       </div>
#      </div>
#      <div class="col-xs-6 col-sm-3 sidebar-offcanvas" id="sidebar" role="navigation">
#       <div class="word-break hidden-print" id="ds-options">
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_browse">
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Acerca de Repositorio
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="https://drive.google.com/file/d/1kGPvFsEKkd75tNh2e_V6y6OR7JkMzDrI/view?usp=sharing">
#          Instructivo
#         </a>
#         <a class="list-group-item ds-option" href="http://www.unp.edu.pe/repositorio/">
#          Reglamento
#         </a>
#         <a class="list-group-item ds-option" href="https://repositorio.unp.edu.pe/cgi-bin/awstats.pl">
#          Estadísticas
#         </a>
#         <br/>
#        </div>
#        <div class="ds-option-set" id="ds-search-option">
#         <form action="/discover" class="" id="ds-search-form" method="post">
#          <fieldset>
#           <div class="input-group">
#            <input class="ds-text-field form-control" name="query" placeholder="Búsquedas" type="text"/>
#            <span class="input-group-btn">
#             <button class="ds-button-field btn btn-primary" title="Ir">
#              <span aria-hidden="true" class="glyphicon glyphicon-search">
#              </span>
#             </button>
#            </span>
#           </div>
#           <div class="radio">
#            <label>
#             <input checked="" id="ds-search-form-scope-all" name="scope" type="radio" value=""/>
#             Buscar en DSpace
#            </label>
#           </div>
#           <div class="radio">
#            <label>
#             <input id="ds-search-form-scope-container" name="scope" type="radio" value="UNP/1304"/>
#             Esta colección
#            </label>
#           </div>
#          </fieldset>
#         </form>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Listar
#        </h2>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_browse">
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Todo DSpace
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/community-list">
#          Comunidades &amp; Colecciones
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=dateissued">
#          Por fecha de publicación
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=author">
#          Autores
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=title">
#          Títulos
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=subject">
#          Materias
#         </a>
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Esta colección
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=dateissued">
#          Por fecha de publicación
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=author">
#          Autores
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=title">
#          Títulos
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=subject">
#          Materias
#         </a>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Mi cuenta
#        </h2>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_account">
#         <a class="list-group-item ds-option" href="/login">
#          Acceder
#         </a>
#         <a class="list-group-item ds-option" href="/register">
#          Registro
#         </a>
#        </div>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_context">
#        </div>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_administrative">
#        </div>
#        <div class="list-group" id="aspect_discovery_Navigation_list_discovery">
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Estadísticas
#        </h2>
#        <div class="list-group" id="aspect_statistics_Navigation_list_statistics">
#         <a class="list-group-item ds-option" href="/handle/20.500.12676/3728/statistics">
#          Ver Estadísticas de uso
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="hidden-xs hidden-sm">
#     <div>
#      <div class="col-xs-2">
#       <a href="#" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/logor2.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="//scholar.google.com/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/googleacademico.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="//duraspace.org/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/duraspace.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="//alicia.concytec.gob.pe/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/alicia.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="http://roar.eprints.org/1348/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/roar.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="https://v2.sherpa.ac.uk/id/repository/4814" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/opendoar.png"/>
#       </a>
#      </div>
#     </div>
#     <footer>
#      <div class="row">
#       <div class="col-xs-12 bg-primary">
#        <h5>
#         Universidad Nacional de Piura
#        </h5>
#        <p>
#         Urb. Miraflores s/n, Castilla-Piura Apartado Postal 295 - Perú | Telf. (51 73) 284700 – 285251 Fax (51 73) 34-3349
#        </p>
#        <p>
#         Todos los contenidos de repositorio.unp.edu.pe están bajo la Licencia Creative Commons
#        </p>
#        <p>
#         <a href="mailto:repositorio@unp.edu.pe" style="color: #FFF;">
#          repositorio@unp.edu.pe
#         </a>
#        </p>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script type="text/javascript">
#    if(typeof window.publication === 'undefined'){
#                             window.publication={};
#                           };
#                         window.publication.contextPath= '';window.publication.themePath= '/themes/Mirage2/';
#   </script>
#   <script>
#    if(!window.DSpace){window.DSpace={};}window.DSpace.context_path='';window.DSpace.theme_path='/themes/Mirage2/';
#   </script>
#   <script src="/themes/Mirage2/scripts/theme.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### 3. Extraemos la información de la primera tesis en un orden adecuado

# %%
caja = soup.find('div', class_="ds-table-responsive") ### Establecemos los parámetros de la información que vamos a utilizar

### De la "caja" extraemos la información necesaria guíandonos del texto del cuadro y extrayendo el texto con la información
titulo = caja.find("td", text = "dc.title").find_next_sibling("td").text 

asesor = caja.find("td", text = "dc.contributor.advisor").find_next_sibling("td").text

autor = caja.find("td", text = "dc.contributor.author").find_next_sibling("td").text

resumen = caja.find("td", text = "dc.description.abstract").find_next_sibling("td").text

uni = caja.find("td", text = "dc.source").find_next_sibling("td").text

año = caja.find("td", text = "dc.date.issued").find_next_sibling("td").text

grado = caja.find("td", text = "thesis.degree.name").find_next_sibling("td").text

# %%
import pandas as pd
# Generando el dataframe

df = pd.DataFrame({'Institución': [uni],
                   'Título': [titulo],
                   'Autor': [autor],
                   'Grado': [grado],
                   'Asesor': [asesor],
                   'Resumen': [resumen],
                   'Año': [año]})
df
# Out:
#                      Institución  \
# 0  Universidad Nacional de Piura
#
#                                               Título  \
# 0  Pronósticos trimestrales de la deuda pública e...
#
#                          Autor                      Grado  \
# 0  Facundo Farfán, Jean Carlos  Licenciado en Estadística
#
#                            Asesor  \
# 0  Cabrera Prieto, Carlos Eduardo
#
#                                              Resumen   Año
# 0  Como es bien sabido, desde hace muchos años, l...  2021

# %% [markdown]
# ### 4. Automatización de la descarga en csv

# %%
df.to_csv('Reportefinal', encoding = 'utf-8')
#Gracias a la herramienta de pandas hemos pasado el dataframe a un archivo con la extensión csv,
#para su posterior análisis en excel.

# %% [markdown]
# ## Listado
#
# Ya que la prueba fue exitosa, se procederá a realizar con toda la lista de tesis del repositorio

# %% [markdown]
# ### 1. Leyendo el primer repositorio de la Universidad Nacional de Piura

# %%
#  1. Requerimiento 

website = 'https://repositorio.unp.edu.pe/handle/UNP/1304'
print('Haciendo una solicitud a:\n')
print(website)

listado_unp = requests.get(website)
listado_unp #Indica el status. 200 significa 'Respuesta satisfactoria'
# Out:
# Haciendo una solicitud a:
#
# https://repositorio.unp.edu.pe/handle/UNP/1304
# <Response [200]>

# %%
#  2. Scrapear con BS

    # a. Almacenar el texto en una 'sopa'
    
sopa_unp = bs(listado_unp.text,'lxml') #'lxml' es el parse que pide la fx
                        # Lo que hace es dividir el texto en 
                            # pequenos pedazos identificables
                        # El resultado es una 'sopa'
    # b. Imprimir texto
print(sopa_unp.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <link href="/themes/Mirage2/images/favicon.ico" rel="shortcut icon"/>
#   <link href="/themes/Mirage2/images/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <meta content="DSpace 6.3" name="Generator"/>
#   <script crossorigin="anonymous" integrity="sha384-3LK/3kTpDE/Pkp8gTNp2gR/2gOiwQ6QaO7Td0zV76UFJVhqLl4Vl3KL1We6q6wR9" src="https://use.fontawesome.com/releases/v5.1.0/js/all.js">
#   </script>
#   <link href="/themes/Mirage2/styles/main.css" rel="stylesheet"/>
#   <link href="/feed/rss_1.0/UNP/1304" rel="alternate" type="application/rss+xml"/>
#   <link href="/feed/rss_2.0/UNP/1304" rel="alternate" type="application/rss+xml"/>
#   <link href="/feed/atom_1.0/UNP/1304" rel="alternate" type="application/atom+xml"/>
#   <link href="https://repositorio.unp.edu.pe:443/open-search/description.xml" rel="search" title="DSpace" type="application/opensearchdescription+xml"/>
#   <script>
#    //Clear default text of empty text areas on focus
#                 function tFocus(element)
#                 {
#                 if (element.value == ' '){element.value='';}
#                 }
#                 //Clear default text of empty text areas on submit
#                 function tSubmit(form)
#                 {
#                 var defaultedElements = document.getElementsByTagName("textarea");
#                 for (var i=0; i != defaultedElements.length; i++){
#                 if (defaultedElements[i].value == ' '){
#                 defaultedElements[i].value='';}}
#                 }
#                 //Disable pressing 'enter' key to submit a form (otherwise pressing 'enter' causes a submission to start over)
#                 function disableEnterKey(e)
#                 {
#                 var key;
#
#                 if(window.event)
#                 key = window.event.keyCode;     //Internet Explorer
#                 else
#                 key = e.which;     //Firefox and Netscape
#
#                 if(key == 13)  //if "Enter" pressed, then disable!
#                 return false;
#                 else
#                 return true;
#                 }
#   </script>
#   <!--[if lt IE 9]>
#                 <script src="/themes/Mirage2/vendor/html5shiv/dist/html5shiv.js"> </script>
#                 <script src="/themes/Mirage2/vendor/respond/dest/respond.min.js"> </script>
#                 <![endif]-->
#   <script src="/themes/Mirage2/vendor/modernizr/modernizr.js">
#   </script>
#   <title>
#    Escuela Profesional de Estadística
#   </title>
#  </head>
#  <body>
#   <header>
#    <div class="navbar navbar-default navbar-static-top" role="navigation">
#     <div class="container">
#      <div class="navbar-header">
#       <button class="navbar-toggle" data-toggle="offcanvas" type="button">
#        <span class="sr-only">
#         Cambiar navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#       <a href="/">
#        <img src="/themes/Mirage2/images/logounp.png" style="display:block;height:auto;max-width:100%;"/>
#       </a>
#       <div class="navbar-header pull-right visible-xs hidden-sm hidden-md hidden-lg">
#        <ul class="nav nav-pills pull-left">
#         <li>
#          <form action="/login" method="get" style="display: inline">
#           <button class="navbar-toggle navbar-link">
#            <b aria-hidden="true" class="visible-xs glyphicon glyphicon-user">
#            </b>
#           </button>
#          </form>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="navbar-header pull-right hidden-xs">
#       <ul class="nav navbar-nav pull-left">
#       </ul>
#       <ul class="nav navbar-nav pull-left">
#        <li>
#         <a href="/login">
#          <span class="hidden-xs">
#           Login
#          </span>
#         </a>
#        </li>
#       </ul>
#       <button class="navbar-toggle visible-sm" data-toggle="offcanvas" type="button">
#        <span class="sr-only">
#         Cambiar navegación
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#     </div>
#    </div>
#   </header>
#   <div class="trail-wrapper hidden-print">
#    <div class="container">
#     <div class="row">
#      <div class="col-xs-12">
#       <div class="breadcrumb dropdown visible-xs">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#" id="trail-dropdown-toggle" role="button">
#         Escuela Profesional de Estadística
#         <b class="caret">
#         </b>
#        </a>
#        <ul aria-labelledby="trail-dropdown-toggle" class="dropdown-menu" role="menu">
#         <li role="presentation">
#          <a href="/" role="menuitem">
#           <i aria-hidden="true" class="glyphicon glyphicon-home">
#           </i>
#           Repositorio Institucional UNP
#          </a>
#         </li>
#         <li role="presentation">
#          <a href="/handle/UNP/1043" role="menuitem">
#           Facultad de Ciencias
#          </a>
#         </li>
#         <li class="disabled" role="presentation">
#          <a href="#" role="menuitem">
#           Escuela Profesional de Estadística
#          </a>
#         </li>
#        </ul>
#       </div>
#       <ul class="breadcrumb hidden-xs">
#        <li>
#         <i aria-hidden="true" class="glyphicon glyphicon-home">
#         </i>
#         <a href="/">
#          Repositorio Institucional UNP
#         </a>
#        </li>
#        <li>
#         <a href="/handle/UNP/1043">
#          Facultad de Ciencias
#         </a>
#        </li>
#        <li class="active">
#         Escuela Profesional de Estadística
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="hidden" id="no-js-warning-wrapper">
#    <div id="no-js-warning">
#     <div class="notice failure">
#      JavaScript is disabled for your browser. Some features of this site may not work without it.
#     </div>
#    </div>
#   </div>
#   <div class="container" id="main-container">
#    <div class="row row-offcanvas row-offcanvas-right">
#     <div class="horizontal-slider clearfix">
#      <div class="col-xs-12 col-sm-12 col-md-9 main-content">
#       <div>
#        <h2 class="ds-div-head page-header first-page-header">
#         Escuela Profesional de Estadística
#        </h2>
#        <div class="ds-static-div primary repository collection" id="aspect_artifactbrowser_CollectionViewer_div_collection-home">
#         <div class="ds-static-div secondary search-browse" id="aspect_artifactbrowser_CollectionViewer_div_collection-search-browse">
#          <div class="ds-static-div secondary browse" id="aspect_browseArtifacts_CollectionBrowse_div_collection-browse">
#           <h3 class="ds-div-head">
#            Listar por
#           </h3>
#           <div class="ds-static-div collection-browse" id="aspect_browseArtifacts_CollectionBrowse_list_collection-browse">
#            <p class="ds-paragraph btn-group">
#             <a class="btn btn-default" href="/handle/UNP/1304/browse?type=dateissued">
#              Por fecha de publicación
#             </a>
#             <a class="btn btn-default" href="/handle/UNP/1304/browse?type=author">
#              Autores
#             </a>
#             <a class="btn btn-default" href="/handle/UNP/1304/browse?type=title">
#              Títulos
#             </a>
#             <a class="btn btn-default" href="/handle/UNP/1304/browse?type=subject">
#              Materias
#             </a>
#            </p>
#           </div>
#          </div>
#          <form action="/handle/UNP/1304/discover" class="ds-interactive-div secondary search" id="aspect_discovery_CollectionSearch_div_collection-search" method="post" onsubmit="javascript:tSubmit(this);">
#           <p>
#            Búsqueda en esta colección:
#           </p>
#           <div class="row">
#            <div class="col-sm-6" id="aspect_discovery_CollectionSearch_p_search-query">
#             <p class="input-group">
#              <input class="ds-text-field form-control" id="aspect_discovery_CollectionSearch_field_query" name="query" type="text" value=""/>
#              <span class="input-group-btn">
#               <button class="ds-button-field btn btn-default" id="aspect_discovery_CollectionSearch_field_submit" name="submit" type="submit">
#                Ir
#               </button>
#              </span>
#             </p>
#            </div>
#           </div>
#          </form>
#         </div>
#         <div class="ds-static-div secondary" id="aspect_artifactbrowser_CollectionViewer_div_collection-view">
#          <!-- External Metadata URL: cocoon://metadata/handle/UNP/1304/mets.xml-->
#          <div class="detail-view">
#           <div class="detail-view-rights-and-license">
#            <p class="copyright-text">
#             <font face="Verdana" size="1">
#              <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/" rel="license">
#               <img alt="Licencia Creative Commons" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" style="border-width:0"/>
#              </a>
#              <br/>
#              Esta obra está bajo una
#              <a href="http://creativecommons.org/licenses/by-nc-sa/4.0/" rel="license">
#               Licencia Creative Commons Atribución-NoComercial-CompartirIgual 4.0 Internacional
#              </a>
#              .
#             </font>
#            </p>
#           </div>
#          </div>
#         </div>
#         <h3 class="ds-div-head">
#          Envíos recientes
#         </h3>
#         <div class="ds-static-div secondary recent-submission" id="aspect_discovery_CollectionRecentSubmissions_div_collection-recent-submission">
#          <ul class="ds-artifact-list list-unstyled">
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/3728/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item odd">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/3728">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3728/ESTA-FAC-FAR-2021.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/3728">
#                 Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F3728&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17876062&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-8528-0472&amp;rft.author=72029939">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Facundo Farfán, Jean Carlos
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2021
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                Como es bien sabido, desde hace muchos años, la deuda pública externa, está constituida por los créditos externos recibidos, donde estos pueden ser tanto públicos como privados. Siempre existe la participación activa de ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/3719/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item even">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/3719">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3719/ESTA-ARE-BAY-2022.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/3719">
#                 Pronóstico de la producción de arroz en cáscara en el Perú mediante modelos SARIMA, año 2022-2023
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F3719&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17930402&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0003-3479-3232&amp;rft.author=73120089&amp;rft.author=73051774">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Arechaga Pacheco, Daniela Antonieta
#                  </span>
#                  ;
#                  <span>
#                   Bayona Gutiérrez, Gina del Pilar
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2022
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                El objetivo del presente estudio es pronosticar la producción de arroz en cáscara en el Perú en base a la producción de los meses de enero del 2010 hasta septiembre 2021 registrada en la página web del Banco Central de ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/3699/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item odd">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/3699">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3699/ESTA-CAR-PAN-2022.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/3699">
#                 Comportamiento de las ventas en formación continua en los institutos Idat y Zegel Ipae a nivel nacional, periodo 2016- 2022-05
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F3699&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=42238686&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-0048-2711&amp;rft.author=70001182&amp;rft.author=71321812">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Carrera Seminario, María Alejandra
#                  </span>
#                  ;
#                  <span>
#                   Panta Martínez, Cirladangela Mercedes
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2022
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                El objetivo de la presente investigación es determinar el comportamiento de las ventas en Formación Continua en los Institutos Idat y Zegel Ipae en los periodos 2016 -2022-05 a nivel nacional, el cual será medido por el ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/3666/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item even">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/3666">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3666/ESTA-LAM-TAB-2022.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/3666">
#                 Uso de redes neuronales para pronosticar los impuestos tributarios mensuales de la Municipalidad Provincial de Morropón, año 2022-2023
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F3666&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17930402&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0003-3479-3232&amp;rft.author=75661177&amp;rft.author=72904920">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Lamadrid Moreno, Leydi Alessandra
#                  </span>
#                  ;
#                  <span>
#                   Taboada Zapata, Willian Daniel Eligio
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2022
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                Esta presente investigación tuvo la finalidad de pronosticar los Impuestos de Administración Tributaria de la Municipalidad Provincial de Morropón – Chulucanas para el periodo 2022-2023, utilizando una data histórica mensual ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/3303/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item odd">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/3303">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3303/ESTA-SIL-NOR-2021.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/3303">
#                 Aplicación del modelo de regresión ordinal para determinar los factores que influyen en el nivel de satisfacción de los pacientes asegurados sobre la atención recibida por consulta externa en las instituciones de salud del Perú, INEI-SUSALUD - 2015
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F3303&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17904174&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-0091-1416&amp;rft.author=70038457">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Silva Noriega, Milady Lakira
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2021
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                En la presente investigación se propone realizar el análisis de los datos de SUSALUD mediante un modelo de regresión logística ordinal con dos opciones de SPSS 24, el módulo de modelos lineales generalizados y métodos de ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2939/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item even">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2939">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2939/ESTA-ARI-JAI-2021.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2939">
#                 Modelo de regresión lineal semi-logarítmico para determinar las variables que se relacionan con el ingreso mensual de la población peruana, según información del INEI, año 2016
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F2939&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=18130328&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0001-8250-5667&amp;rft.author=43957971">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Arias Jaime, Jhoan Manuel
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2021
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                La presente investigación titulada: “Aplicación del modelo lineal semi-logaritmico para determinar las variables que se relacionan con el ingreso mensual de la población peruana, año 2016”; fue planteada como una investigación ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2875/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item odd">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2875">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2875/ESTA-SAL-PAM-2019.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2875">
#                 Las redes sociales y su relación con el rendimiento académico de los estudiantes de quinto año del nivel secundario de la Institución educativa Micaela Bastidas- 2019
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F2875&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=19199852&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-3656-1788&amp;rft.author=71234916">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Salazar Pampas, Jean Carlos
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2019
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                La presente investigación titulada “Las redes sociales y su relación con el rendimiento académico de los estudiantes de Quinto año del Nivel secundario de la Institución Educativa Micaela Bastidas-2019”, tiene por objetivo ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2689/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item even">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2689">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2689/ESTA-PAN-IPA-2021.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2689">
#                 Modelo de regresión logística aplicado con técnicas de balanceo de datos para clasificar el ingreso de los postulantes a la Facultad de Ciencias de la Universidad Nacional de Piura
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F2689&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=19199852&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-3656-1788&amp;rft.author=73695711">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Panta Ipanaqué, Juan Camilo
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2021
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                En la actualidad los clasificadores predictivos están siendo muy utilizados, por lo cual existen varios métodos que nos ofrecen resultados buenos para solucionar esta tarea, sin embargo, es probable encontrarse con conjuntos ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2550/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item odd">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2550">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2550/ESTA-QUI-VIL-2019.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2550">
#                 Análisis de las denuncias registradas por infracción a la ley N° 30364 “Ley para prevenir, sancionar y erradicar la violencia contra las mujeres y los integrantes del grupo familiar” en el departamento de Piura desde enero del 2016 a octubre del 2019
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F2550&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17904174&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-0091-1416&amp;rft.author=72880147&amp;rft.author=72847432">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Quiroga Girón, Rosanna Stephanie
#                  </span>
#                  ;
#                  <span>
#                   Vílchez Sosa, Jeanifer Katherine
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2019
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                La investigación ha tenido por finalidad realizar un análisis descriptivo de las denuncias registradas por infracción a la ley N°30364 “Ley para prevenir, sancionar y erradicar la violencia contra las mujeres y los integrantes ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2549/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item even">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2549">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2549/ESTA-DED-HER-2019.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2549">
#                 Pronóstico del número de accidentes de tránsito mediante suavización exponencial doble, región Piura 1991- 2019
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F2549&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=02628517&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0002-2153-7443&amp;rft.author=76633223&amp;rft.author=71106155">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Dedios Morales, Darlyn Marilyn Lucero
#                  </span>
#                  ;
#                  <span>
#                   Hernández Cañola, Patricia Micheline
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   PE
#                  </span>
#                  ,
#                  <span class="date">
#                   2019
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                El presente trabajo de investigación tuvo como objetivo general pronosticar el número de accidentes de tránsito, en la región Piura 1991-2019, mediante suavización exponencial doble. Para complementar la investigación como ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2548/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item odd">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2548">
#                <img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2548/ESTA-ABA-PAN-2020.png?sequence=4&amp;isAllowed=y"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2548">
#                 Modelación y pronóstico de las atenciones en el servicio de hospitalización en el Hospital de la Amistad Perú – Corea II-2 Santa Rosa aplicando modelos ARIMA. Piura.Perú 2020 – 2021
#                </a>
#                <span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Adc&amp;rft_id=http%3A%2F%2Frepositorio.unp.edu.pe%2Fhandle%2F20.500.12676%2F2548&amp;rfr_id=info%3Asid%2Fdspace.org%3Arepository&amp;rft.degree=Licenciado+en+Estad%C3%ADstica&amp;rft.degree=Universidad+Nacional+de+Piura.+Facultad+de+Ciencias&amp;rft.degree=Estad%C3%ADstica&amp;rft.advisor=17930402&amp;rft.advisor=https%3A%2F%2Forcid.org%2F0000-0003-3479-3232&amp;rft.author=71035824">
#                 ﻿
#                </span>
#               </h4>
#               <div class="artifact-info">
#                <span class="author h4">
#                 <small>
#                  <span>
#                   Abad Panta, Cristina Elizabeth
#                  </span>
#                 </small>
#                </span>
#                <span class="publisher-date h4">
#                 <small>
#                  (
#                  <span class="publisher">
#                   Universidad Nacional de PiuraPE
#                  </span>
#                  ,
#                  <span class="date">
#                   2020
#                  </span>
#                  )
#                 </small>
#                </span>
#               </div>
#               <div class="open-access">
#                <svg aria-hidden="true" class="svg-inline--fa fa-lock-open fa-w-18 fa-fw" data-fa-i2svg="" data-icon="lock-open" data-prefix="fas" role="img" viewbox="0 0 576 512">
#                 <path d="M423.5 0C339.5.3 272 69.5 272 153.5V224H48c-26.5 0-48 21.5-48 48v192c0 26.5 21.5 48 48 48h352c26.5 0 48-21.5 48-48V272c0-26.5-21.5-48-48-48h-48v-71.1c0-39.6 31.7-72.5 71.3-72.9 40-.4 72.7 32.1 72.7 72v80c0 13.3 10.7 24 24 24h32c13.3 0 24-10.7 24-24v-80C576 68 507.5-.3 423.5 0z" fill="currentColor">
#                 </path>
#                </svg>
#                <span>
#                 Acceso Abierto
#                </span>
#               </div>
#               <div class="artifact-abstract">
#                Esta investigación se realizó con el objetivo de pronosticar el número de atenciones para los años 2020 y 2021 en el servicio de Hospitalización del hospital de la amistad Perú-Corea Santa Rosa II-2, mediante la aplicación ...
#               </div>
#              </div>
#             </div>
#            </div>
#           </li>
#           <!-- External Metadata URL: cocoon://metadata/handle/20.500.12676/2264/mets.xml?sections=dmdSec,fileSec&fileGrpTypes=THUMBNAIL-->
#           <li class="ds-artifact-item even">
#            <div class="item-wrapper row">
#             <div class="col-sm-3 hidden-xs">
#              <div class="thumbnail artifact-preview">
#               <a class="image-link" href="/handle/20.500.12676/2264">
#                <img alt="Thumbnail" class="img-thumbnail" data-src="holder.js/100%x160/text:No Thumbnail"/>
#               </a>
#              </div>
#             </div>
#             <div class="col-sm-9">
#              <div class="artifact-description">
#               <h4 class="artifact-title">
#                <a href="/handle/20.500.12676/2264">
#                 Pronóstico de los ingresos tributarios mensuales del gobierno central peruano aplicando redes neuronales y modelos Sarima, en base a los años 2003 – 2018
#                </a>
# ...
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/duraspace.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="//alicia.concytec.gob.pe/" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/alicia.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="http://roar.eprints.org/1348/" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/roar.png"/>
#          </a>
#         </div>
#         <div class="col-xs-2">
#          <a href="https://v2.sherpa.ac.uk/id/repository/4814" target="_blank">
#           <img alt="" class="img-responsive" src="/themes/Mirage2/images/opendoar.png"/>
#          </a>
#         </div>
#        </div>
#        <footer>
#         <div class="row">
#          <div class="col-xs-12 bg-primary">
#           <h5>
#            Universidad Nacional de Piura
#           </h5>
#           <p>
#            Urb. Miraflores s/n, Castilla-Piura Apartado Postal 295 - Perú | Telf. (51 73) 284700 – 285251 Fax (51 73) 34-3349
#           </p>
#           <p>
#            Todos los contenidos de repositorio.unp.edu.pe están bajo la Licencia Creative Commons
#           </p>
#           <p>
#            <a href="mailto:repositorio@unp.edu.pe" style="color: #FFF;">
#             repositorio@unp.edu.pe
#            </a>
#           </p>
#          </div>
#         </div>
#        </footer>
#       </div>
#      </div>
#      <div class="col-xs-6 col-sm-3 sidebar-offcanvas" id="sidebar" role="navigation">
#       <div class="word-break hidden-print" id="ds-options">
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_browse">
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Acerca de Repositorio
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="https://drive.google.com/file/d/1kGPvFsEKkd75tNh2e_V6y6OR7JkMzDrI/view?usp=sharing">
#          Instructivo
#         </a>
#         <a class="list-group-item ds-option" href="http://www.unp.edu.pe/repositorio/">
#          Reglamento
#         </a>
#         <a class="list-group-item ds-option" href="https://repositorio.unp.edu.pe/cgi-bin/awstats.pl">
#          Estadísticas
#         </a>
#         <br/>
#        </div>
#        <div class="ds-option-set" id="ds-search-option">
#         <form action="/discover" class="" id="ds-search-form" method="post">
#          <fieldset>
#           <div class="input-group">
#            <input class="ds-text-field form-control" name="query" placeholder="Búsquedas" type="text"/>
#            <span class="input-group-btn">
#             <button class="ds-button-field btn btn-primary" title="Ir">
#              <span aria-hidden="true" class="glyphicon glyphicon-search">
#              </span>
#             </button>
#            </span>
#           </div>
#           <div class="radio">
#            <label>
#             <input checked="" id="ds-search-form-scope-all" name="scope" type="radio" value=""/>
#             Buscar en DSpace
#            </label>
#           </div>
#           <div class="radio">
#            <label>
#             <input id="ds-search-form-scope-container" name="scope" type="radio" value="UNP/1304"/>
#             Esta colección
#            </label>
#           </div>
#          </fieldset>
#         </form>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Listar
#        </h2>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_browse">
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Todo DSpace
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/community-list">
#          Comunidades &amp; Colecciones
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=dateissued">
#          Por fecha de publicación
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=author">
#          Autores
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=title">
#          Títulos
#         </a>
#         <a class="list-group-item ds-option" href="/browse?type=subject">
#          Materias
#         </a>
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Esta colección
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=dateissued">
#          Por fecha de publicación
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=author">
#          Autores
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=title">
#          Títulos
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/browse?type=subject">
#          Materias
#         </a>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Mi cuenta
#        </h2>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_account">
#         <a class="list-group-item ds-option" href="/login">
#          Acceder
#         </a>
#         <a class="list-group-item ds-option" href="/register">
#          Registro
#         </a>
#        </div>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_context">
#        </div>
#        <div class="list-group" id="aspect_viewArtifacts_Navigation_list_administrative">
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Descubre
#        </h2>
#        <div class="list-group" id="aspect_discovery_Navigation_list_discovery">
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Autor
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Abad+Panta%2C+Cristina+Elizabeth">
#          Abad Panta, Cristina Elizabeth (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Arechaga+Pacheco%2C+Daniela+Antonieta">
#          Arechaga Pacheco, Daniela Antonieta (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Arias+Jaime%2C+Jhoan+Manuel">
#          Arias Jaime, Jhoan Manuel (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Bayona+Guti%C3%A9rrez%2C+Gina+del+Pilar">
#          Bayona Gutiérrez, Gina del Pilar (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Bruno+Ram%C3%ADrez%2C+Xenia+Stefany">
#          Bruno Ramírez, Xenia Stefany (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Carrera+Seminario%2C+Mar%C3%ADa+Alejandra">
#          Carrera Seminario, María Alejandra (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Chapilliquen+Rosillo%2C+Vanessa">
#          Chapilliquen Rosillo, Vanessa (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Dedios+Morales%2C+Darlyn+Marilyn+Lucero">
#          Dedios Morales, Darlyn Marilyn Lucero (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Eche+Anton%2C+Alex+Martin">
#          Eche Anton, Alex Martin (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=author&amp;filter_relational_operator=equals&amp;filter=Facundo+Farf%C3%A1n%2C+Jean+Carlos">
#          Facundo Farfán, Jean Carlos (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/search-filter?field=author&amp;filterorder=COUNT">
#          ... más
#         </a>
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Materia
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=http%3A%2F%2Fpurl.org%2Fpe-repo%2Focde%2Fford%231.01.03">
#          http://purl.org/pe-repo/ocde/ford#1.01.03 (13)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Ciencias+Naturales">
#          Ciencias Naturales (8)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Estad%C3%ADsticas+y+Probabilidades">
#          Estadísticas y Probabilidades (3)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Factores+de+riesgo">
#          Factores de riesgo (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=ODDS+RATIO">
#          ODDS RATIO (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Poblaci%C3%B3n">
#          Población (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Pron%C3%B3stico">
#          Pronóstico (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=pron%C3%B3sticos">
#          pronósticos (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Proyecci%C3%B3n">
#          Proyección (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=subject&amp;filter_relational_operator=equals&amp;filter=Regresi%C3%B3n+Log%C3%ADstica">
#          Regresión Logística (2)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/search-filter?field=subject&amp;filterorder=COUNT">
#          ... más
#         </a>
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Fecha
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2019">
#          2019 (9)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2018">
#          2018 (4)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2021">
#          2021 (4)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2020">
#          2020 (3)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2022">
#          2022 (3)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2013">
#          2013 (1)
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=dateIssued&amp;filter_relational_operator=equals&amp;filter=2017">
#          2017 (1)
#         </a>
#         <a class="list-group-item active">
#          <span class="h5 list-group-item-heading h5">
#           Has File(s)
#          </span>
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/discover?filtertype=has_content_in_original_bundle&amp;filter_relational_operator=equals&amp;filter=true">
#          Yes (25)
#         </a>
#        </div>
#        <h2 class="ds-option-set-head h6">
#         Estadísticas
#        </h2>
#        <div class="list-group" id="aspect_statistics_Navigation_list_statistics">
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/statistics">
#          Ver Estadísticas de uso
#         </a>
#         <a class="list-group-item ds-option" href="/handle/UNP/1304/search-statistics">
#          Ver Estadísticas de Búsquedas
#         </a>
#        </div>
#        <div>
#         <h2 class="ds-option-set-head h6">
#          RSS Feeds
#         </h2>
#         <div class="ds-option-set list-group" id="ds-feed-option">
#          <a class="list-group-item" href="/feed/rss_1.0/UNP/1304">
#           <img alt="feed" class="btn-xs" src="/static/icons/feed.png"/>
#           RSS 1.0
#          </a>
#          <a class="list-group-item" href="/feed/rss_2.0/UNP/1304">
#           <img alt="feed" class="btn-xs" src="/static/icons/feed.png"/>
#           RSS 2.0
#          </a>
#          <a class="list-group-item" href="/feed/atom_1.0/UNP/1304">
#           <img alt="feed" class="btn-xs" src="/static/icons/feed.png"/>
#           Atom
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="hidden-xs hidden-sm">
#     <div>
#      <div class="col-xs-2">
#       <a href="#" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/logor2.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="//scholar.google.com/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/googleacademico.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="//duraspace.org/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/duraspace.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="//alicia.concytec.gob.pe/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/alicia.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="http://roar.eprints.org/1348/" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/roar.png"/>
#       </a>
#      </div>
#      <div class="col-xs-2">
#       <a href="https://v2.sherpa.ac.uk/id/repository/4814" target="_blank">
#        <img alt="" class="img-responsive" src="/themes/Mirage2/images/opendoar.png"/>
#       </a>
#      </div>
#     </div>
#     <footer>
#      <div class="row">
#       <div class="col-xs-12 bg-primary">
#        <h5>
#         Universidad Nacional de Piura
#        </h5>
#        <p>
#         Urb. Miraflores s/n, Castilla-Piura Apartado Postal 295 - Perú | Telf. (51 73) 284700 – 285251 Fax (51 73) 34-3349
#        </p>
#        <p>
#         Todos los contenidos de repositorio.unp.edu.pe están bajo la Licencia Creative Commons
#        </p>
#        <p>
#         <a href="mailto:repositorio@unp.edu.pe" style="color: #FFF;">
#          repositorio@unp.edu.pe
#         </a>
#        </p>
#       </div>
#      </div>
#     </footer>
#    </div>
#   </div>
#   <script type="text/javascript">
#    if(typeof window.publication === 'undefined'){
#                             window.publication={};
#                           };
#                         window.publication.contextPath= '';window.publication.themePath= '/themes/Mirage2/';
#   </script>
#   <script>
#    if(!window.DSpace){window.DSpace={};}window.DSpace.context_path='';window.DSpace.theme_path='/themes/Mirage2/';
#   </script>
#   <script src="/themes/Mirage2/scripts/theme.js">
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### 2. Extraemos el url de cada tesis

# %%
# d. Extraer url de cada tesis 

tesis = sopa_unp.find('ul', attrs = {'class':'ds-artifact-list list-unstyled'}).find_all('a')
print(tesis)
# Out:
# [<a class="image-link" href="/handle/20.500.12676/3728"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3728/ESTA-FAC-FAR-2021.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/3728">Pronósticos trimestrales de la deuda pública externa peruana aplicando modelos de series de tiempo para el año 2022</a>, <a class="image-link" href="/handle/20.500.12676/3719"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3719/ESTA-ARE-BAY-2022.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/3719">Pronóstico de la producción de arroz en cáscara en el Perú mediante modelos SARIMA, año 2022-2023</a>, <a class="image-link" href="/handle/20.500.12676/3699"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3699/ESTA-CAR-PAN-2022.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/3699">Comportamiento de las ventas en formación continua en los institutos Idat y Zegel Ipae a nivel nacional, periodo 2016- 2022-05</a>, <a class="image-link" href="/handle/20.500.12676/3666"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3666/ESTA-LAM-TAB-2022.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/3666">Uso de redes neuronales para pronosticar los impuestos tributarios mensuales de la Municipalidad Provincial de Morropón, año 2022-2023</a>, <a class="image-link" href="/handle/20.500.12676/3303"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/3303/ESTA-SIL-NOR-2021.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/3303">Aplicación del modelo de regresión ordinal para determinar los factores que influyen en el nivel de satisfacción de los pacientes asegurados sobre la atención recibida por consulta externa en las instituciones de salud del Perú, INEI-SUSALUD - 2015</a>, <a class="image-link" href="/handle/20.500.12676/2939"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2939/ESTA-ARI-JAI-2021.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/2939">Modelo de regresión lineal semi-logarítmico para determinar las variables que se relacionan con el ingreso mensual de la población peruana, según información del INEI, año 2016</a>, <a class="image-link" href="/handle/20.500.12676/2875"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2875/ESTA-SAL-PAM-2019.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/2875">Las redes sociales y su relación con el rendimiento académico de los estudiantes de quinto año del nivel secundario de la Institución educativa Micaela Bastidas- 2019</a>, <a class="image-link" href="/handle/20.500.12676/2689"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2689/ESTA-PAN-IPA-2021.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/2689">Modelo de regresión logística aplicado con técnicas de balanceo de datos para clasificar el ingreso de los postulantes a la Facultad de Ciencias de la Universidad Nacional de Piura</a>, <a class="image-link" href="/handle/20.500.12676/2550"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2550/ESTA-QUI-VIL-2019.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20.500.12676/2550">Análisis de las denuncias registradas por infracción a la ley N° 30364 “Ley para prevenir, sancionar y erradicar la violencia contra las mujeres y los integrantes del grupo familiar” en el departamento de Piura desde enero del 2016 a octubre del 2019</a>, <a class="image-link" href="/handle/20.500.12676/2549"><img alt="Thumbnail" class="img-responsive img-thumbnail" src="/bitstream/handle/20.500.12676/2549/ESTA-DED-HER-2019.png?sequence=4&amp;isAllowed=y"/></a>, <a href="/handle/20 ...
# ['https://repositorio.unp.edu.pe/handle/20.500.12676/3728',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3719',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3699',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3666',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3303',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2939',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2875',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2689',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2550',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2549',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2548',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2264',
#  'https://repositorio.unp.edu.pe/handle/UNP/2113',
#  'https://repositorio.unp.edu.pe/handle/UNP/2112',
#  'https://repositorio.unp.edu.pe/handle/UNP/2111',
#  'https://repositorio.unp.edu.pe/handle/UNP/2110',
#  'https://repositorio.unp.edu.pe/handle/UNP/2031',
#  'https://repositorio.unp.edu.pe/handle/UNP/2014',
#  'https://repositorio.unp.edu.pe/handle/UNP/2013',
#  'https://repositorio.unp.edu.pe/handle/UNP/1824']

# %%
# Obteniendo los urls y generando una lista con ellos

urls_unp=[]
validador=2

for url in tesis:
    if validador%2==0:
        a=website[0:30]+url.get('href')
        urls_unp.append(a)
    validador+=1
        
urls_unp
# Out:
# ['https://repositorio.unp.edu.pe/handle/20.500.12676/3728',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3719',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3699',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3666',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/3303',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2939',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2875',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2689',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2550',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2549',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2548',
#  'https://repositorio.unp.edu.pe/handle/20.500.12676/2264',
#  'https://repositorio.unp.edu.pe/handle/UNP/2113',
#  'https://repositorio.unp.edu.pe/handle/UNP/2112',
#  'https://repositorio.unp.edu.pe/handle/UNP/2111',
#  'https://repositorio.unp.edu.pe/handle/UNP/2110',
#  'https://repositorio.unp.edu.pe/handle/UNP/2031',
#  'https://repositorio.unp.edu.pe/handle/UNP/2014',
#  'https://repositorio.unp.edu.pe/handle/UNP/2013',
#  'https://repositorio.unp.edu.pe/handle/UNP/1824']

# %% [markdown]
# ### 3. Extraemos la información de la primera tesis en un orden adecuado

# %%
#  1. Hacer el requerimiento a cada tesis en un bucle for

for url in urls_unp:
    a=requests.get(url)
#    print(a)
    if a.status_code == 200:
          print('Solicitud a ', url,' satisfactoria\n')

# %%
#  2. Scrapear con BS

titulos=[]


for url in urls_unp:
    a=requests.get(url)
    if a.status_code == 200:
        #print('Solicitud a ', url,' satisfactoria\n')
        caja2=bs(a.text,'lxml')
        #print(caja2.prettify())
        # Extraigo los aspectos de la tesis
        titulo = caja2.find("td", text = "dc.title").find_next_sibling("td").text 
        #titulos.append(titulos)
#print(titulos)
        

        
        
# asesores = caja.find("td", text = "dc.contributor.advisor").find_next_sibling("td").text

# autores = caja.find("td", text = "dc.contributor.author").find_next_sibling("td").text

#resumenes = caja.find("td", text = "dc.description.abstract").find_next_sibling("td").text

#universidades = caja.find("td", text = "dc.source").find_next_sibling("td").text

#años = caja.find("td", text = "dc.date.issued").find_next_sibling("td").text

#grados = caja.find("td", text = "thesis.degree.name").find_next_sibling("td").text

# %%
#  2. Generando el dataframe con cada aspecto de todas las tesis

df_total = pd.DataFrame({'Institución': [universidades],
                   'Título': [titulos],
                   'Autor': [autores],
                   'Grado': [grados],
                   'Asesor': [asesores],
                   'Resumen': [resumenes],
                   'Año': [años]})
df_total

# %% [markdown]
# ### 4. Automatización de la descarga en csv

# %%
df_total.to_csv('Reportefinal', encoding = 'utf-8')

#Gracias a la herramienta de pandas hemos pasado el dataframe a un archivo con la extensión csv,
#para su posterior análisis en excel.
